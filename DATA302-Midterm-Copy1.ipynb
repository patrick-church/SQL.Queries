# %%
import nyc_db
from importlib import reload
reload(nyc_db);
from nyc_db import DB
import pandas as pd
import sqlite3
import dbga
from collections import defaultdict as dd
import json

# %%
my_sql = dd(dict)

# %%
my_sql['setup'] = []

# %%
conn = sqlite3.connect('databases/nyc_health.db')
curs = conn.cursor()

# %%
data = pd.read_csv('nyc_rest_health_inspections.csv')
data.head(2)
# Out:
#       CAMIS                DBA       BORO BUILDING         STREET  ZIPCODE  \
# 0  40511702  NOTARO RESTAURANT  MANHATTAN      635  SECOND AVENUE  10016.0
# 1  40511702  NOTARO RESTAURANT  MANHATTAN      635  SECOND AVENUE  10016.0
#
#         PHONE CUISINE DESCRIPTION INSPECTION DATE  \
# 0  2126863400             Italian      06/15/2015
# 1  2126863400             Italian      11/25/2014
#
#                                             ACTION VIOLATION CODE  \
# 0  Violations were cited in the following area(s).            02B
# 1  Violations were cited in the following area(s).            20F
#
#                          VIOLATION DESCRIPTION
# 0  Hot food item not held at or above 140Âº F.
# 1        Current letter grade card not posted.

# %% [markdown]
# ---
# 1) Get a list of all restaurants (by camis) who have been cited for a violation containing the words 'vermin', 'mice', or 'rats'.
#
# Have your query return the following columns:
# - camis
# - dba
# - viol_id
# - viol_desc
# - A count of the number of times they have been cited for each violation
#
# Order the results with the most violations on top.

# %%
sql1 = '''
SELECT camis, dba, viol_desc, viol_id, count(*) as NumViol
FROM tInsp
JOIN tViol USING(viol_id)
JOIN tRest USING(camis)
WHERE viol_desc LIKE "%vermin%" OR viol_desc LIKE "%mice%" OR viol_desc LIKE "%rats%"
GROUP BY camis, viol_desc
ORDER BY NumViol DESC
;'''
pd.read_sql(sql1, conn)
# Out:
#           camis                                dba  \
# 0      40861669             NEW VICTORY RESTAURANT
# 1      41430594                  1 STOP PATTY SHOP
# 2      50033122  PARTY WELL REST & ORIENTAL BAKERY
# 3      40861669             NEW VICTORY RESTAURANT
# 4      41309387                   NEW TACO EXPRESS
# ...         ...                                ...
# 29033  50068060                    TASTE OF PUNJAB
# 29034  50068098                             SUBWAY
# 29035  50068305                       SONRISA AZUL
# 29036  50068537           JOE & THE JUICE COLOMBUS
# 29037  50068537           JOE & THE JUICE COLOMBUS
#
#                                                viol_desc viol_id  NumViol
# 0      Facility not vermin proof. Harborage or condit...     08A       15
# 1      Evidence of mice or live mice present in facil...     04L       14
# 2      Facility not vermin proof. Harborage or condit...     08A       14
# 3      Evidence of mice or live mice present in facil...     04L       13
# 4      Evidence of mice or live mice present in facil...     04L       13
# ...                                                  ...     ...      ...
# 29033  Facility not vermin proof. Harborage or condit...     08A        1
# 29034  Facility not vermin proof. Harborage or condit...     08A        1
# 29035  Facility not vermin proof. Harborage or condit...     08A        1
# 29036  Evidence of mice or live mice present in facil...     04L        1
# 29037  Facility not vermin proof. Harborage or condit...     08A        1
#
# [29038 rows x 5 columns]

# %% [markdown]
# ---
# 2) For each different cuisine type, determine the most commonly cited violation **excluding viol_id 10F** (this is by far the most common violation, and not very "gross").
#
# Have your query return:
#
# - cuisine
# - viol_id
# - viol_desc
# - Number of violations for their most common violation (except 10F)
#
# Limit those results to cuisine types where the max number of violations is greater than 1000.
#
# Order the results in ascending order by the cuisine type.

# %%
sql2 = '''
WITH
ViolBYCuisineViol_id as 
(
    SELECT count(*) as NumViol, cuisine, viol_id, viol_desc
    FROM tInsp
    JOIN tViol USING(viol_id)
    JOIN tRest USING(camis)
    GROUP BY cuisine, viol_id
)

SELECT cuisine, viol_id, viol_desc, max(NumViol) as NumViol
FROM (ViolBYCuisineViol_id)
WHERE viol_id NOT LIKE "%10f%"
GROUP BY cuisine
HAVING NumViol > 1000
ORDER BY cuisine ASC
;'''
pd.read_sql(sql2, conn)
# Out:
#                                               cuisine viol_id  \
# 0                                            American     08A
# 1                                              Bakery     08A
# 2                                    CafÃ©/Coffee/Tea     08A
# 3                                           Caribbean     08A
# 4                                             Chinese     08A
# 5                                             Italian     08A
# 6                                            Japanese     08A
# 7   Latin (Cuban, Dominican, Puerto Rican, South &...     08A
# 8                                             Mexican     08A
# 9                                               Pizza     08A
# 10                                            Spanish     08A
#
#                                             viol_desc  NumViol
# 0   Facility not vermin proof. Harborage or condit...     8573
# 1   Facility not vermin proof. Harborage or condit...     1355
# 2   Facility not vermin proof. Harborage or condit...     1308
# 3   Facility not vermin proof. Harborage or condit...     1697
# 4   Facility not vermin proof. Harborage or condit...     4438
# 5   Facility not vermin proof. Harborage or condit...     1575
# 6   Facility not vermin proof. Harborage or condit...     1360
# 7   Facility not vermin proof. Harborage or condit...     2065
# 8   Facility not vermin proof. Harborage or condit...     1586
# 9   Facility not vermin proof. Harborage or condit...     2111
# 10  Facility not vermin proof. Harborage or condit...     1235

# %% [markdown]
# ---
#
# 3) When the action description contains the word 'closed', what are the top 5 associated violations?
#
#
# Have your query return:
#
# - action_desc
# - viol_desc
# - total number of violations
#
# Order the results with the largest number of violations on top

# %%
sql3 = '''
SELECT action_desc, viol_desc, count(*) as NumViol
FROM tInsp
JOIN tViol USING(viol_id)
JOIN tAction USING(action_id)
WHERE action_desc LIKE "%closed%"
GROUP BY viol_desc
ORDER BY NumViol DESC
LIMIT 5
;'''
pd.read_sql(sql3, conn)
# Out:
#                                          action_desc  \
# 0  Establishment Closed by DOHMH.  Violations wer...
# 1  Establishment Closed by DOHMH.  Violations wer...
# 2  Establishment Closed by DOHMH.  Violations wer...
# 3  Establishment Closed by DOHMH.  Violations wer...
# 4  Establishment Closed by DOHMH.  Violations wer...
#
#                                            viol_desc  NumViol
# 0  Facility not vermin proof. Harborage or condit...     1656
# 1  Evidence of mice or live mice present in facil...     1148
# 2  Live roaches present in facility's food and/or...      715
# 3  Cold food item held above 41Âº F (smoked fish ...      691
# 4  Non-food contact surface improperly constructe...      640

# %% [markdown]
# ---
#
# 4) Determine which restaurant has been closed the most (action description contains 'closed').
#
# For that camis, have your query return:
#
# - camis
# - dba
# - viol_desc
# - total number of violations per violation type
#
# Include all violations for that camis (not just the ones they were closed for)
#
# Order the results with the most common violation on top

# %%
sql4 = '''
WITH
MostClosedCamis as
(
    SELECT count(*) as MostClosed, camis, dba
    FROM tInsp
    JOIN tViol USING(viol_id)
    JOIN tAction USING(action_id)
    JOIN tRest USING(camis)
    WHERE action_desc LIKE "%closed%"
    GROUP BY camis
    ORDER BY MostClosed DESC
    LIMIT 1
)


SELECT camis, dba, viol_desc, count(*) as NumViol
FROM tInsp
JOIN tViol USING(viol_id)
JOIN tAction USING(action_id)
JOIN tRest USING(camis)
WHERE camis LIKE (SELECT camis FROM MostClosedCamis)
GROUP BY viol_id
ORDER BY NumViol DESC
;'''
pd.read_sql(sql4, conn)
# Out:
#        camis                            dba  \
# 0   40922818  EL TAPATIO MEXICAN RESTAURANT
# 1   40922818  EL TAPATIO MEXICAN RESTAURANT
# 2   40922818  EL TAPATIO MEXICAN RESTAURANT
# 3   40922818  EL TAPATIO MEXICAN RESTAURANT
# 4   40922818  EL TAPATIO MEXICAN RESTAURANT
# 5   40922818  EL TAPATIO MEXICAN RESTAURANT
# 6   40922818  EL TAPATIO MEXICAN RESTAURANT
# 7   40922818  EL TAPATIO MEXICAN RESTAURANT
# 8   40922818  EL TAPATIO MEXICAN RESTAURANT
# 9   40922818  EL TAPATIO MEXICAN RESTAURANT
# 10  40922818  EL TAPATIO MEXICAN RESTAURANT
# 11  40922818  EL TAPATIO MEXICAN RESTAURANT
# 12  40922818  EL TAPATIO MEXICAN RESTAURANT
# 13  40922818  EL TAPATIO MEXICAN RESTAURANT
# 14  40922818  EL TAPATIO MEXICAN RESTAURANT
# 15  40922818  EL TAPATIO MEXICAN RESTAURANT
# 16  40922818  EL TAPATIO MEXICAN RESTAURANT
# 17  40922818  EL TAPATIO MEXICAN RESTAURANT
# 18  40922818  EL TAPATIO MEXICAN RESTAURANT
# 19  40922818  EL TAPATIO MEXICAN RESTAURANT
# 20  40922818  EL TAPATIO MEXICAN RESTAURANT
# 21  40922818  EL TAPATIO MEXICAN RESTAURANT
#
#                                             viol_desc  NumViol
# 0   Non-food contact surface improperly constructe...        8
# 1   Facility not vermin proof. Harborage or condit...        7
# 2   Live roaches present in facility's food and/or...        7
# 3   Plumbing not properly installed or maintained;...        5
# 4   Evidence of rats or live rats present in facil...        5
# 5   Cold food item held above 41Âº F (smoked fish ...        4
# 6   Failure to comply with an Order of the Board o...        3
# 7   The original nutritional fact labels and/or in...        3
# 8   Food Protection Certificate not held by superv...        3
# 9         Hot food item not held at or above 140Âº F.        3
# 10  Food not protected from potential source of co...        2
# 11  Personal cleanliness inadequate. Outer garment...        2
# 12  Filth flies or food/refuse/sewage-associated (...        2
# 13      Food contact surface not properly maintained.        1
# 14  Pesticide use not in accordance with label or ...        1
# 15  Wiping cloths soiled or not stored in sanitizi...        1
# 16  Sanitized equipment or utensil, including in-u...        1
# 17  Tobacco use, eating, or drinking from open con...        1
# 18  Insufficient or no refrigerated or hot holding...        1
# 19  Shellfish not from approved source, improperly...        1
# 20  Food from unapproved or unknown source or home...        1
# 21  Food not cooled by an approved method whereby ...        1

# %% [markdown]
# ---
#
# 5) Group all restaurants by their DBA, and computer the average number of violations per location.
#
# For example, if there were 100 restaurants with the dba "STARBUCKS", and they had a total of 123 violations, then the average number of violations per location would be 123/100=1.23.
#
# Have your query return:
# - dba
# - Number of locations
# - Number of violations
# - Avg violations per location
#
# Order the results with the largest number of locations on top
#
# _Watch out for integer division!_

# %%
sql5 = '''

SELECT dba, TotalRestNum, NumViol, 1.0*NumViol/TotalRestNum as AvgViolsPerLoc
FROM (
    SELECT count(DISTINCT(camis)) as TotalRestNum, count(camis) as NumViol, dba
    FROM tInsp
    JOIN tViol USING(viol_id)
    JOIN tAction USING(action_id)
    JOIN tRest USING(camis)
    GROUP BY dba
    ORDER by TotalRestNum DESC
    )

;'''
pd.read_sql(sql5, conn)
# Out:
#                                   dba  TotalRestNum  NumViol  AvgViolsPerLoc
# 0                      DUNKIN' DONUTS           410     4247       10.358537
# 1                              SUBWAY           352     3729       10.593750
# 2                           STARBUCKS           281     2130        7.580071
# 3                          MCDONALD'S           206     2778       13.485437
# 4      DUNKIN' DONUTS, BASKIN ROBBINS           110     1462       13.290909
# ...                               ...           ...      ...             ...
# 20242                        $1 PIZZA             1        8        8.000000
# 20243      #1 SABOR LATINO RESTAURANT             1       55       55.000000
# 20244            #1 Natural Juice Bar             1        6        6.000000
# 20245               #1 GARDEN CHINESE             1       27       27.000000
# 20246           #1 Chinese Restaurant             1        3        3.000000
#
# [20247 rows x 4 columns]

# %% [markdown]
# ---
#
# 6) For restaurants (by DBA) with only a single location (i.e., DBA with exactly 1 associated CAMIS) and more than 10 total violations, what is their top violation, and how many times have they been cited for it?
#
# Note that a restaurant might have been cited 1 time each for 10 different types of violations, and 2 times for another violation. That would be 12 total violations, which counts as more than 10.
#
# **Limit your results** to cases where their top violation occurred greater than or equal to 15 times.
#
# Have your query return:
#
# - camis
# - dba
# - viol_desc
# - number of violations
#
# Order your results by number of violations, descending.

# %%
#20247 rows of dba's total
#18908 restuarnats with only one camis
#11620 restaurnats with 10 or more viols with only one camis

# %%
sql6 = '''
WITH
RestList as
(
SELECT camis, dba, count(DISTINCT(camis)) as GetRest, viol_id
FROM tInsp
JOIN tViol USING(viol_id)
JOIN tRest USING(camis)
GROUP BY dba
HAVING GetRest = 1
),
TotalViolNum as
(
SELECT camis, dba, count(*) as NumViol
FROM tInsp
JOIN tViol USING(viol_id)
JOIN tRest USING(camis)
WHERE camis IN (SELECT camis FROM RestList)
GROUP BY dba
HAVING NumViol > 10
ORDER BY NumViol
),

NoMore as
(
SELECT camis, dba, count(*) as NumViol, viol_desc
FROM tInsp
    JOIN tViol USING(viol_id)
    JOIN tRest USING(camis)
WHERE camis IN (SELECT camis FROM TotalViolNum)
GROUP BY dba, viol_id
ORDER BY NumViol DESC
)

SELECT camis, dba, viol_desc, Max(NumViol) as NumViol
FROM NoMore
GROUP BY dba
HAVING NumViol >= 15
ORDER BY NumViol DESC

;'''
pd.read_sql(sql6, conn)
# Out:
#       camis                     dba  \
# 0  40861669  NEW VICTORY RESTAURANT
#
#                                            viol_desc  NumViol
# 0  Facility not vermin proof. Harborage or condit...       15

# %% [markdown]
# ---
#
# 7) Considering all possible combinations of violation/action, how many of those combinations **do not occur** in the data?
#
# Have your query return just the total number.

# %%
sql7 = '''
WITH
AllCombs as
  (
   SELECT viol_id, action_id
   FROM tViol
   JOIN tAction
  ),
HasOccurred as
  (
   SELECT DISTINCT viol_id, action_id
   FROM tInsp
  )
SELECT count(*)
FROM(
SELECT AllCombs.action_id, AllCombs.viol_id, HasOccurred.action_id
FROM AllCombs
LEFT JOIN HasOccurred USING(action_id, viol_id)
WHERE HasOccurred.action_id IS NULL
)
;'''
pd.read_sql(sql7, conn)
# Out:
#    count(*)
# 0       221

# %% [markdown]
# ---
#
# 8) Return the action and violation descriptions associated with the previous question.
#
# Have your query return:
#
# - action_desc
# - viol_desc
#
# Order your results in ascending order by viol_desc

# %%
sql8 = '''
WITH
AllCombs as
  (
  SELECT viol_id, action_id
  FROM tViol
  JOIN tAction
  ),
HasOccurred as
  (
  SELECT DISTINCT viol_id, action_id
  FROM tInsp
  )
SELECT action_desc, viol_desc
FROM AllCombs
LEFT JOIN HasOccurred USING(action_id, viol_id)
JOIN tViol USING(viol_id)
JOIN tAction USING(action_id)
WHERE HasOccurred.action_id IS NULL
ORDER BY viol_desc ASC
;'''
pd.read_sql(sql8, conn)
# Out:
#                                            action_desc  \
# 0    Establishment Closed by DOHMH.  Violations wer...
# 1                     Establishment re-opened by DOHMH
# 2                     Establishment re-closed by DOHMH
# 3                     Establishment re-closed by DOHMH
# 4    No violations were recorded at the time of thi...
# ..                                                 ...
# 216                   Establishment re-opened by DOHMH
# 217                   Establishment re-closed by DOHMH
# 218  No violations were recorded at the time of thi...
# 219                   Establishment re-closed by DOHMH
# 220  No violations were recorded at the time of thi...
#
#                                              viol_desc
# 0    ''''No Smoking and/or 'Smoking Permitted sig...
# 1    ''''No Smoking and/or 'Smoking Permitted sig...
# 2    ''''No Smoking and/or 'Smoking Permitted sig...
# 3    ''''Wash hands sign not posted at hand wash f...
# 4    ''''Wash hands sign not posted at hand wash f...
# ..                                                 ...
# 216  Whole frozen poultry or poultry breasts, other...
# 217  Whole frozen poultry or poultry breasts, other...
# 218  Whole frozen poultry or poultry breasts, other...
# 219  Wiping cloths soiled or not stored in sanitizi...
# 220  Wiping cloths soiled or not stored in sanitizi...
#
# [221 rows x 2 columns]

# %% [markdown]
# ---
#
# 9) For all restaurants (by camis) that have been cited for 90 or more violations, what is their top violation?
#
# Have your query return:
# - camis
# - dba
# - viol_id
# - viol_desc
# - Number of violations (for the top violation only)
#
# Order the results in ascending order by dba

# %%
sql9 = '''
WITH 
NumViol_90_ as 
  (
  SELECT count(*) as NumViol, camis, dba
  FROM tInsp
  JOIN tRest USING(camis)
  JOIN tViol USING(viol_id)
  GROUP BY camis
  HAVING NumViol >= 90
  ),
ViolByCamis as
  (
  SELECT camis, dba, viol_id, viol_desc, count(*) as NumViol
  FROM tInsp
  JOIN tRest USING(camis)
  JOIN tViol USING(viol_id)
  WHERE camis IN (SELECT camis FROM NumViol_90_)
  GROUP BY viol_id, camis
  )
SELECT camis, dba, viol_id, viol_desc, max(NumViol) as NumViol
FROM ViolByCamis
GROUP BY camis
ORDER BY dba ASC
;'''
pd.read_sql(sql9, conn)
# Out:
#       camis                                dba viol_id  \
# 0  50001880                      GANG SAN DEUL     02B
# 1  40965177                  LA GATA GOLOSA #2     06C
# 2  41683816            MAX BAKERY & RESTAURANT     04M
# 3  50033122  PARTY WELL REST & ORIENTAL BAKERY     08A
# 4  41459659                      T. K. KITCHEN     08A
#
#                                            viol_desc  NumViol
# 0        Hot food item not held at or above 140Âº F.       10
# 1  Food not protected from potential source of co...        8
# 2  Live roaches present in facility's food and/or...       12
# 3  Facility not vermin proof. Harborage or condit...       14
# 4  Facility not vermin proof. Harborage or condit...       13

# %%
conn.close()
